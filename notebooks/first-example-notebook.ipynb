# %% [markdown]
# ## This is a "Markdown" cell. Markdown is a special syntax of language that is interpreted as the HTML language.
#
# Although not as fully descriptive as the HTML language and associated tool (i.e., "the Internet"), it is a simple way to write in plain text and preserve nice formatting.

# %%
## This is a code cell. Jupyter notebooks typically can support many languages. 
# The name Jupyter is derived from the 3 languages originally envisioned for support: *Ju*lia, *Pyt*hon, and *R*.
print(f"Hello, world")
